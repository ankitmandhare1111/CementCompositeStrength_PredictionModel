# %% [markdown]
# # Step 1 :
# ## Import Basix Scikit Learn Libraries for Data Manipulation as well Data Visualization.

# %%
# Import Data Manipulation Libraries
import numpy as np
import pandas as pd

# import Data Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Import Data Filter Warnings
import warnings
warnings.filterwarnings("ignore")

# Import Data Logging Libraries
import logging
logging.basicConfig(level=logging.INFO,
                    filename="model.log",
                    filemode="w",
                    format="%(asctime)s - %(levelname)s - %(message)s"
                    )

# %% [markdown]
# # Step 2 :
# ## Data Uploading Using Pandas Function

# %%
# Load the Dataset

url = "https://raw.githubusercontent.com/ankitmandhare1111/CementCompositeStrength_PredictionModel/refs/heads/main/concrete_data.csv"

df = pd.read_csv(url,sep= ",")

df.sample(frac = 1)
# Out:
#      cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 409   167.4               129.9    128.6  175.5               7.8
# 101   388.6                97.1      0.0  157.9              12.1
# 425   167.0                75.4    167.0  164.0               7.9
# 335   275.1                 0.0    121.4  159.5               9.9
# 455   213.5                 0.0    174.2  159.2              11.7
# ..      ...                 ...      ...    ...               ...
# 456   194.7                 0.0    100.5  170.2               7.5
# 645   203.5               305.3      0.0  203.5               0.0
# 206   212.1                 0.0    121.6  180.3               5.7
# 904   155.0               183.0      0.0  193.0               9.0
# 575   238.1                 0.0      0.0  185.7               0.0
#
#      coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 409            1006.3            746.6    3                          14.94
# 101             852.1            925.7    7                          34.90
# 425            1007.3            770.1   14                          32.90
# 335            1053.6            777.5   14                          38.77
# 455            1043.6            771.9   56                          51.26
# ..                ...              ...  ...                            ...
# 456             998.0            901.8   56                          43.39
# 645             963.4            630.0    7                          19.54
# 206            1057.6            779.3   28                          24.90
# 904             877.0            868.0   28                          23.79
# 575            1118.8            789.3   28                          17.58
#
# [1030 rows x 9 columns]

# %% [markdown]
# # Step 3 :
# ## Doing Exporatory Data Analysis [EDA] :-->
#
# **Univariate Analysis**
#
# **Bi Variate Analysis**

# %%
# Perform Univariate Analysis
from collections import OrderedDict

stats =  [] 

for i in df.columns:
    numerical_stats = OrderedDict({
        'Feature': i,
        'Type': df[i].dtype,
        'Missing': df[i].isnull().sum(),
        'Unique': df[i].nunique(),
        'Mode': df[i].mode().values[0],
        'Mean': df[i].mean(),
        'Median': df[i].median(),
        'Standard Deviation': df[i].std(),
        'Min': df[i].min(),
        'Max': df[i].max(),
        'Range': df[i].max() - df[i].min(),
        'Skewness': df[i].skew(),
        'Kurtosis': df[i].kurt(),
        'IQR' : df[i].quantile(0.75) - df[i].quantile(0.25)
    })
    
    stats.append(numerical_stats)

df_stats = pd.DataFrame(stats)

df_stats.style.background_gradient(subset= ["Missing", "Unique", "Mode", "Mean", "Median", "Standard Deviation", "Min", "Max", "Range", "Skewness", "Kurtosis", "IQR"], cmap = "Reds")
# Out:
# <style type="text/css">
# #T_f58b3_row0_col2, #T_f58b3_row1_col2, #T_f58b3_row1_col4, #T_f58b3_row1_col8, #T_f58b3_row2_col2, #T_f58b3_row2_col4, #T_f58b3_row2_col6, #T_f58b3_row2_col8, #T_f58b3_row2_col12, #T_f58b3_row3_col2, #T_f58b3_row4_col2, #T_f58b3_row4_col4, #T_f58b3_row4_col5, #T_f58b3_row4_col7, #T_f58b3_row4_col8, #T_f58b3_row4_col9, #T_f58b3_row4_col10, #T_f58b3_row4_col13, #T_f58b3_row5_col2, #T_f58b3_row6_col2, #T_f58b3_row6_col11, #T_f58b3_row7_col2, #T_f58b3_row7_col3, #T_f58b3_row7_col8, #T_f58b3_row8_col2, #T_f58b3_row8_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f58b3_row0_col3 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_f58b3_row0_col4 {
#   background-color: #fc8e6e;
#   color: #000000;
# }
# #T_f58b3_row0_col5, #T_f58b3_row0_col6 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_f58b3_row0_col7, #T_f58b3_row0_col10, #T_f58b3_row0_col13, #T_f58b3_row5_col4, #T_f58b3_row5_col5, #T_f58b3_row5_col6, #T_f58b3_row5_col8, #T_f58b3_row5_col9, #T_f58b3_row7_col11, #T_f58b3_row7_col12, #T_f58b3_row8_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f58b3_row0_col8 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_f58b3_row0_col9 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_f58b3_row0_col11, #T_f58b3_row3_col3 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_f58b3_row0_col12, #T_f58b3_row1_col12, #T_f58b3_row5_col11 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_f58b3_row1_col3, #T_f58b3_row3_col4 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_f58b3_row1_col5 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_f58b3_row1_col6 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_f58b3_row1_col7 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_f58b3_row1_col9 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_f58b3_row1_col10, #T_f58b3_row6_col6 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_f58b3_row1_col11, #T_f58b3_row7_col9 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_f58b3_row1_col13 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_f58b3_row2_col3 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_f58b3_row2_col5 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_f58b3_row2_col7 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_f58b3_row2_col9, #T_f58b3_row3_col8 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_f58b3_row2_col10 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_f58b3_row2_col11 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_f58b3_row2_col13 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_f58b3_row3_col5 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_f58b3_row3_col6, #T_f58b3_row8_col11 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_f58b3_row3_col7 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_f58b3_row3_col9 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_f58b3_row3_col10 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_f58b3_row3_col11, #T_f58b3_row6_col12 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_f58b3_row3_col12, #T_f58b3_row8_col7 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_f58b3_row3_col13, #T_f58b3_row4_col3 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_f58b3_row4_col6 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_f58b3_row4_col11 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_f58b3_row4_col12 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_f58b3_row5_col3 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_f58b3_row5_col7 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_f58b3_row5_col10 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_f58b3_row5_col12 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_f58b3_row5_col13 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col3 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_f58b3_row6_col4 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col5 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col7 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col8 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col9 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col10 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_f58b3_row6_col13 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_f58b3_row7_col4, #T_f58b3_row7_col6, #T_f58b3_row8_col5 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_f58b3_row7_col5 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_f58b3_row7_col7 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_f58b3_row7_col10 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_f58b3_row7_col13 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_f58b3_row8_col4, #T_f58b3_row8_col6 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_f58b3_row8_col9 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_f58b3_row8_col10 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_f58b3_row8_col12 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_f58b3_row8_col13 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# </style>
# <table id="T_f58b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f58b3_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_f58b3_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_f58b3_level0_col2" class="col_heading level0 col2" >Missing</th>
#       <th id="T_f58b3_level0_col3" class="col_heading level0 col3" >Unique</th>
#       <th id="T_f58b3_level0_col4" class="col_heading level0 col4" >Mode</th>
#       <th id="T_f58b3_level0_col5" class="col_heading level0 col5" >Mean</th>
#       <th id="T_f58b3_level0_col6" class="col_heading level0 col6" >Median</th>
#       <th id="T_f58b3_level0_col7" class="col_heading level0 col7" >Standard Deviation</th>
#       <th id="T_f58b3_level0_col8" class="col_heading level0 col8" >Min</th>
#       <th id="T_f58b3_level0_col9" class="col_heading level0 col9" >Max</th>
#       <th id="T_f58b3_level0_col10" class="col_heading level0 col10" >Range</th>
#       <th id="T_f58b3_level0_col11" class="col_heading level0 col11" >Skewness</th>
#       <th id="T_f58b3_level0_col12" class="col_heading level0 col12" >Kurtosis</th>
#       <th id="T_f58b3_level0_col13" class="col_heading level0 col13" >IQR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f58b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f58b3_row0_col0" class="data row0 col0" >cement</td>
#       <td id="T_f58b3_row0_col1" class="data row0 col1" >float64</td>
#       <td id="T_f58b3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f58b3_row0_col3" class="data row0 col3" >278</td>
#       <td id="T_f58b3_row0_col4" class="data row0 col4" >362.600000</td>
#       <td id="T_f58b3_row0_col5" class="data row0 col5" >281.167864</td>
#       <td id="T_f58b3_row0_col6" class="data row0 col6" >272.900000</td>
#       <td id="T_f58b3_row0_col7" class="data row0 col7" >104.506364</td>
#       <td id="T_f58b3_row0_col8" class="data row0 col8" >102.000000</td>
#       <td id="T_f58b3_row0_col9" class="data row0 col9" >540.000000</td>
#       <td id="T_f58b3_row0_col10" class="data row0 col10" >438.000000</td>
#       <td id="T_f58b3_row0_col11" class="data row0 col11" >0.509481</td>
#       <td id="T_f58b3_row0_col12" class="data row0 col12" >-0.520652</td>
#       <td id="T_f58b3_row0_col13" class="data row0 col13" >157.625000</td>
#     </tr>
#     <tr>
#       <th id="T_f58b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f58b3_row1_col0" class="data row1 col0" >blast_furnace_slag</td>
#       <td id="T_f58b3_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_f58b3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f58b3_row1_col3" class="data row1 col3" >185</td>
#       <td id="T_f58b3_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f58b3_row1_col5" class="data row1 col5" >73.895825</td>
#       <td id="T_f58b

# %%
# Checking Correlation Matrix
# X = Independent Variables
# y =  Dependent Variable ---> ['concrete_compressive_strength']
# annot is for Displaying Numbers inside cell
sns.heatmap(df.corr(),annot=True, yticklabels=True,center= 0,vmax=1, vmin= -1 , cmap = "Reds")
plt.title("Correlation Matrix")
plt.show()
# X = df.drop('concrete_compressive_strength', axis = 1 )

# %%
# understanding feature and create new features based on existing features ----> feature engineering

df.corr()['concrete_compressive_strength']
# Out:
# cement                           0.497832
# blast_furnace_slag               0.134829
# fly_ash                         -0.105755
# water                           -0.289633
# superplasticizer                 0.366079
# coarse_aggregate                -0.164935
# fine_aggregate                  -0.167241
# age                              0.328873
# concrete_compressive_strength    1.000000
# Name: concrete_compressive_strength, dtype: float64

# %%
df['composite_Ratio']= (df['cement'] + df['superplasticizer']+ df['blast_furnace_slag'])/(df['water'])+ df['coarse_aggregate']

# %%
df
# Out:
#       cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       coarse_aggregate  fine_aggregate   age  concrete_compressive_strength  \
# 0               1040.0            676.0   28                          79.99
# 1               1055.0            676.0   28                          61.89
# 2                932.0            594.0  270                          40.27
# 3                932.0            594.0  365                          41.05
# 4                978.4            825.5  360                          44.30
# ...                ...              ...  ...                            ...
# 1025             870.1            768.3   28                          44.28
# 1026             817.9            813.4   28                          31.18
# 1027             892.4            780.0   28                          23.70
# 1028             989.6            788.9   28                          32.77
# 1029             864.5            761.5   28                          32.40
#
#       composite_Ratio
# 0         1043.348765
# 1         1058.348765
# 2          934.083333
# 3          934.083333
# 4          980.123958
# ...               ...
# 1025       872.334410
# 1026       819.596939
# 1027       893.925688
# 1028       991.633599
# 1029       866.344467
#
# [1030 rows x 10 columns]

# %%
df['cement_to_water_ratio'] = df['cement'] /  df['water']

# %%
df
# Out:
#       cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       coarse_aggregate  fine_aggregate   age  concrete_compressive_strength  \
# 0               1040.0            676.0   28                          79.99
# 1               1055.0            676.0   28                          61.89
# 2                932.0            594.0  270                          40.27
# 3                932.0            594.0  365                          41.05
# 4                978.4            825.5  360                          44.30
# ...                ...              ...  ...                            ...
# 1025             870.1            768.3   28                          44.28
# 1026             817.9            813.4   28                          31.18
# 1027             892.4            780.0   28                          23.70
# 1028             989.6            788.9   28                          32.77
# 1029             864.5            761.5   28                          32.40
#
#       composite_Ratio  cement_to_water_ratio
# 0         1043.348765               3.333333
# 1         1058.348765               3.333333
# 2          934.083333               1.458333
# 3          934.083333               1.458333
# 4          980.123958               1.034375
# ...               ...                    ...
# 1025       872.334410               1.538976
# 1026       819.596939               1.643878
# 1027       893.925688               0.770628
# 1028       991.633599               0.906036
# 1029       866.344467               1.300598
#
# [1030 rows x 11 columns]

# %%
df.corr()['concrete_compressive_strength']
# Out:
# cement                           0.497832
# blast_furnace_slag               0.134829
# fly_ash                         -0.105755
# water                           -0.289633
# superplasticizer                 0.366079
# coarse_aggregate                -0.164935
# fine_aggregate                  -0.167241
# age                              0.328873
# concrete_compressive_strength    1.000000
# composite_Ratio                 -0.159372
# cement_to_water_ratio            0.559522
# Name: concrete_compressive_strength, dtype: float64

# %%
sns.regplot(x =df['composite_Ratio'],y=df['concrete_compressive_strength'])
plt.title('composite ratio vs concrete compressive strength')
plt.show()

# %%
sns.regplot(x =df['composite_Ratio'],y=df['concrete_compressive_strength'])
# Out:
# <Axes: xlabel='composite_Ratio', ylabel='concrete_compressive_strength'>

# %% [markdown]
# #STEP 4 :
#
# ## splitting the data into training and testing sets also useing train and test split to prevent data lekage

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='concrete_compressive_strength', axis = 1)
y =df['concrete_compressive_strength']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X
# Out:
#       cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       coarse_aggregate  fine_aggregate   age  composite_Ratio  \
# 0               1040.0            676.0   28      1043.348765
# 1               1055.0            676.0   28      1058.348765
# 2                932.0            594.0  270       934.083333
# 3                932.0            594.0  365       934.083333
# 4                978.4            825.5  360       980.123958
# ...                ...              ...  ...              ...
# 1025             870.1            768.3   28       872.334410
# 1026             817.9            813.4   28       819.596939
# 1027             892.4            780.0   28       893.925688
# 1028             989.6            788.9   28       991.633599
# 1029             864.5            761.5   28       866.344467
#
#       cement_to_water_ratio
# 0                  3.333333
# 1                  3.333333
# 2                  1.458333
# 3                  1.458333
# 4                  1.034375
# ...                     ...
# 1025               1.538976
# 1026               1.643878
# 1027               0.770628
# 1028               0.906036
# 1029               1.300598
#
# [1030 rows x 10 columns]

# %%
# using scaling techniques
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train= scaler .fit_transform(X_train)
X_test =  scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

LR= LinearRegression()

LR.fit(X_train, y_train)

y_pred_LR = LR.predict(X_test)


from sklearn.metrics import mean_squared_error,r2_score, mean_squared_error

r2_score_LR = r2_score(y_test, y_pred_LR)

r2_score_LR
# Out:
# 0.5941935306287813
